# %%
# %%capture
try:
    from pip import main as pipmain
except:
    from pip._internal import main as pipmain
packages = ['twython']
pipmain(['install'] + packages)

# %%
# %%capture
from twython import Twython

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

import re

# %%
from auth import (
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)

twitter = Twython(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)

# %%
PRINT_LIMIT = 50

# TODO: create a function to random select indexes from followers list
FOLLOWER_SAMPLE_LIMIT = 10 # number of followers to sample
WORD_FREQ_LIMIT = 10 # return this number of topics that are most freq

# %%
user = "AndrewYang"

# %%
followers = twitter.get_followers_ids(screen_name = user)

limit = 0
for follower_id in followers['ids']:
    print('Follower Id: {0} '.format(follower_id))
    limit += 1
    if limit >= PRINT_LIMIT:
        break
# Out:
# Follower Id: 721465654868455425
# Follower Id: 1177946965943967744
# Follower Id: 1083374335220436993
# Follower Id: 1167899227432685569
# Follower Id: 792100649483632641
# Follower Id: 789862930749599744
# Follower Id: 140841885
# Follower Id: 415635097
# Follower Id: 19011327
# Follower Id: 1160928468072390656
# Follower Id: 2752772240
# Follower Id: 2907614065
# Follower Id: 353553564
# Follower Id: 1975435932
# Follower Id: 1179117825929011200
# Follower Id: 869918705735483392
# Follower Id: 866786930
# Follower Id: 1853402665
# Follower Id: 1034400619937710081
# Follower Id: 1055865069295288320
# Follower Id: 1187218460222210048
# Follower Id: 3503997972
# Follower Id: 395644633
# Follower Id: 2445009697
# Follower Id: 1086972514461347841
# Follower Id: 916128590298624000
# Follower Id: 3236190824
# Follower Id: 32569786
# Follower Id: 913945088
# Follower Id: 1021871139587600384
# Follower Id: 320765978
# Follower Id: 1115180965775544325
# Follower Id: 807499487056793600
# Follower Id: 417515326
# Follower Id: 1049904564936339456
# Follower Id: 1168204718180454401
# Follower Id: 883100596143665153
# Follower Id: 117247829
# Follower Id: 863947888761741312
# Follower Id: 1170193203904958465
# Follower Id: 897702186318254083
# Follower Id: 137468560
# Follower Id: 1177012527206686720
# Follower Id: 535433353
# Follower Id: 1092199712
# Follower Id: 2171604118
# Follower Id: 133932984
# Follower Id: 1184572373606944769
# Follower Id: 234629513
# Follower Id: 2350384585

# %%
def get_tweet_data(results):
    tweets = []
    for tweet in results:
        tweet_map = {"text": tweet['text']}
        tweet_hashtags = []
        tweet_urls = []
        tweet_user_mentions = []
        
        entities = tweet['entities']
    
        for hashtags in entities['hashtags']:
            tweet_hashtags.append(hashtags['text'])
        for urls in entities['urls']:
            tweet_urls.append(urls['url'])
        try:
            for media in entities['media']:
                tweet_urls.append(media['url'])
        except:
            pass
        for users in entities['user_mentions']:
            tweet_user_mentions.append(users['screen_name'])
            
        tweet_map["hashtags"] = tweet_hashtags
        tweet_map["urls"] = tweet_urls
        tweet_map["user_mentions"] = tweet_user_mentions
        tweets.append(tweet_map)
        
    return tweets

# %%
def get_tweets_data_from(user_id, results):
    try: 
        result = twitter.get_user_timeline(user_id = user_id)
        results.extend(result)
        return get_tweet_data(result), results
    except:
        return []

# %%
tweets_data = []
results = []
limit = 0
for f in followers['ids']:
    result, results = get_tweets_data_from(f, results)
    tweets_data.extend(result)
    limit += 1
    if limit >= FOLLOWER_SAMPLE_LIMIT:
        break
tweets_data
# Out:
# [{'text': '@NOLAnews No good deed goes unpunished.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['NOLAnews']},
#  {'text': '@custardloaf I like the ones that include a cigarette.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['custardloaf']},
#  {'text': '@TyFox10 @FOX10Phoenix A description of the suspect might be helpful to the residents of Prescott.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TyFox10', 'FOX10Phoenix']},
#  {'text': 'After two large cups of dark roast, the caffeine is finally starting to kick in.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': '@NOLAnews She was in her own home and had the right to protect her family &amp; property.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['NOLAnews']},
#  {'text': 'Here I am.', 'hashtags': [], 'urls': [], 'user_mentions': []},
#  {'text': "I've been playing Elevate to keep my brain sharp. I think you'll like it too. Get it here: https://t.co/ZGBwrBpiVI https://t.co/RNd2jUsBHK",
#   'hashtags': [],
#   'urls': ['https://t.co/ZGBwrBpiVI', 'https://t.co/RNd2jUsBHK'],
#   'user_mentions': []},
#  {'text': 'Thank you! https://t.co/xNTrRNmuYQ',
#   'hashtags': [],
#   'urls': ['https://t.co/xNTrRNmuYQ'],
#   'user_mentions': []},
#  {'text': 'RT @TroyAikman: iCYMI: Talk to me when when he has 33% of my Super Bowl Titles https://t.co/Ba8kjPRnDs',
#   'hashtags': [],
#   'urls': ['https://t.co/Ba8kjPRnDs'],
#   'user_mentions': ['TroyAikman']},
#  {'text': 'RT @nytimes: Greta Thunberg speaks at the UN climate summit: "You all come to us young people for hope? How dare you!"\nRead more: https://t…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['nytimes']},
#  {'text': 'RT @amyklobuchar: Same. https://t.co/NLi5njxfDU',
#   'hashtags': [],
#   'urls': ['https://t.co/NLi5njxfDU'],
#   'user_mentions': ['amyklobuchar']},
#  {'text': 'Heroic bystanders rescue girl after father dies jumping in front of subway train - ABC News - https://t.co/11qFSX3f2Z via @ABC',
#   'hashtags': [],
#   'urls': ['https://t.co/11qFSX3f2Z'],
#   'user_mentions': ['ABC']},
#  {'text': 'Trinity Lawrence is the student name to login in and order !\nPlease help to support Grapevine middle school !❤️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'Please support my fundraiser! https://t.co/eK3MRHbJUS',
#   'hashtags': [],
#   'urls': ['https://t.co/eK3MRHbJUS'],
#   'user_mentions': []},
#  {'text': '❤️❤️Corona Rae ❤️❤️ @ Grapevine, Texas https://t.co/Cae9Fn89mG',
#   'hashtags': [],
#   'urls': ['https://t.co/Cae9Fn89mG'],
#   'user_mentions': []},
#  {'text': 'RT @dharm32: #Classic https://t.co/V3WGvaKOqo',
#   'hashtags': ['Classic'],
#   'urls': ['https://t.co/V3WGvaKOqo'],
#   'user_mentions': ['dharm32']},
#  {'text': 'RT @DatelineNBC: It’s the end of the road for many --  the Louisiana State Penitentiary. Friday at 10/9c, @LesterHoltNBC explores the key i…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['DatelineNBC', 'LesterHoltNBC']},
#  {'text': 'RT @Steveman05: @JulieAnnDobbs  https://t.co/ZEbsxcthBb',
#   'hashtags': [],
#   'urls': ['https://t.co/ZEbsxcthBb'],
#   'user_mentions': ['Steveman05', 'JulieAnnDobbs']},
#  {'text': 'RT @JulieAnnDobbs: Oh dear. https://t.co/IelqcivX8D',
#   'hashtags': [],
#   'urls': ['https://t.co/IelqcivX8D'],
#   'user_mentions': ['JulieAnnDobbs']},
#  {'text': 'RT @dfwticket: We have #JubHawk !! #JubHawk #jubhawk2019 @GeorgeDunham https://t.co/kbcQwREea0',
#   'hashtags': ['JubHawk', 'JubHawk', 'jubhawk2019'],
#   'urls': ['https://t.co/kbcQwREea0'],
#   'user_mentions': ['dfwticket', 'GeorgeDunham']},
#  {'text': 'RT @BetoORourke: LIVE NOW: Beto at Keene State https://t.co/pB4pcR0xHF',
#   'hashtags': [],
#   'urls': ['https://t.co/pB4pcR0xHF'],
#   'user_mentions': ['BetoORourke']},
#  {'text': 'Early bird gets the.. #fish  🎣#liveyourbestlife #miniaussie #catfishingnation #sundayfunday @ Cowboys Golf Club https://t.co/jisZa0ZPWE',
#   'hashtags': ['fish',
#    'liveyourbestlife',
#    'miniaussie',
#    'catfishingnation',
#    'sundayfunday'],
#   'urls': ['https://t.co/jisZa0ZPWE'],
#   'user_mentions': []},
#  {'text': "Donald Trump's latest conspiracy theory target? Fox News.\nhttps://t.co/P7YuFSztVl",
#   'hashtags': [],
#   'urls': ['https://t.co/P7YuFSztVl'],
#   'user_mentions': []},
#  {'text': 'Yasssss ❤️ https://t.co/rhynuBwKwc',
#   'hashtags': [],
#   'urls': ['https://t.co/rhynuBwKwc'],
#   'user_mentions': []},
#  {'text': "My first and last time at #hangmanshouseofhorrors #imababy #halloween #throwback @ Hangman's House of Horrors https://t.co/IeTqLIlIk2",
#   'hashtags': ['hangmanshouseofhorrors', 'imababy', 'halloween', 'throwback'],
#   'urls': ['https://t.co/IeTqLIlIk2'],
#   'user_mentions': []},
#  {'text': 'You are literally my best friend baby #love @ Lonestar Antiques https://t.co/uOTw1TTYMR',
#   'hashtags': ['love'],
#   'urls': ['https://t.co/uOTw1TTYMR'],
#   'user_mentions': []},
#  {'text': "@thehill Maybe, if you weren't such a Dick all the time, you would get better committee assignments.\nBTW - How is y… https://t.co/DrUWIIBmPr",
#   'hashtags': [],
#   'urls': ['https://t.co/DrUWIIBmPr'],
#   'user_mentions': ['thehill']},
#  {'text': "@NightlyPolitics @Debbie56111656 You really, really, can't fix a statement that, STUPID...",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['NightlyPolitics', 'Debbie56111656']},
#  {'text': '@GOPLeader Like the Republicans are doing to Native Americans in North &amp; South Dakota?\nHow can you soon this one??… https://t.co/jqS09nDejw',
#   'hashtags': [],
#   'urls': ['https://t.co/jqS09nDejw'],
#   'user_mentions': ['GOPLeader']},
#  {'text': 'RT @robreiner: Interesting defense tactic. Just continue to admit to the crime. Maybe we won’t notice. Not gonna work. You just admitted yo…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['robreiner']},
#  {'text': '@TheRickWilson #LockThemUp',
#   'hashtags': ['LockThemUp'],
#   'urls': [],
#   'user_mentions': ['TheRickWilson']},
#  {'text': 'RT @amyklobuchar: To: Republican colleagues\nFrom: Everyone else \nDate: Today\nRe: Constitutional duties \n\nAfter diplomat Taylor’s testimony…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['amyklobuchar']},
#  {'text': '@john_sipher @McFaul Two words - Sean Hannity',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['john_sipher', 'McFaul']},
#  {'text': '@sambrodey Not up on Washington DC Speak. What is the SCIF?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['sambrodey']},
#  {'text': 'RT @RichardEngel: Tonight as the Kurdish people look up at the stars here in northern Syria, they have many big decisions to make. Where to…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['RichardEngel']},
#  {'text': "RT @ChrisMurphyCT: Listen, there's now zero doubt what was going on.\n\nThe texts and testimony make it clear the President was using access…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ChrisMurphyCT']},
#  {'text': 'RT @SenatorRomney: The Administration confirmed today that Turkey ignored our warning and that the U.S. blinked by withdrawing our troops f…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SenatorRomney']},
#  {'text': 'RT @mitchellreports: .@brhodes "This is catastrophic outcome he\'s trying to spin-his spin is filled w/ lies. ISIS fighters escaped. He\'s no…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['mitchellreports', 'brhodes']},
#  {'text': 'RT @TheRickWilson: My favorite part of this whole affair today is that the long slow divorce of the Republican party from the rule of law i…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TheRickWilson']},
#  {'text': 'RT @gtconway3d: It’s obviously important for the country that @realDonaldTrump be removed from office for his extraordinary and corrupt abu…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['gtconway3d', 'realDonaldTrump']},
#  {'text': '@GOPLeader Think of the House Hearings as  Grand Jury.\nHave you ever heard of a Grand Jury letting a cross-examinat… https://t.co/zYdbweDx1H',
#   'hashtags': [],
#   'urls': ['https://t.co/zYdbweDx1H'],
#   'user_mentions': ['GOPLeader']},
#  {'text': 'RT @_SJPeace_: He has Cerebral Palsy and wanted to skate board so his mom created this for him so that he could. \n\nMY HEART 😭❤\n\nMother Of T…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['_SJPeace_']},
#  {'text': "RT @RepAdamSchiff: Trump's Chief of Staff admitted military aid was withheld from an ally to get their help with an investigation, which co…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['RepAdamSchiff']},
#  {'text': 'RT @tribelaw: Trump sought a personal favor from Ukraine, “though,” in exchange for the official act of releasing $391 million in military…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['tribelaw']},
#  {'text': '@SteveScalise @realDonaldTrump How did that work out for you Steve?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SteveScalise', 'realDonaldTrump']},
#  {'text': 'RT @SeanEldridge: Republicans in Congress might not believe it, but I and a majority of Americans do:\n\nNo one is above the law in the Unite…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SeanEldridge']},
#  {'text': 'Follow Up to my Tulsi Gabbard Video https://t.co/tTadvLu1f6 via @YouTube',
#   'hashtags': [],
#   'urls': ['https://t.co/tTadvLu1f6'],
#   'user_mentions': ['YouTube']},
#  {'text': '@jljacobson @BernieSanders @TulsiGabbard How did this propagandist get a checkmark??',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jljacobson', 'BernieSanders', 'TulsiGabbard']},
#  {'text': '@PrisonPlanet So true...',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['PrisonPlanet']},
#  {'text': 'This Bitch!!  #Tulsi2020 https://t.co/BAt3vv1m0w',
#   'hashtags': ['Tulsi2020'],
#   'urls': ['https://t.co/BAt3vv1m0w'],
#   'user_mentions': []},
#  {'text': '@Orwell_H0ttie @Panikatax1 @mtracey and change "was" to "is".',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Orwell_H0ttie', 'Panikatax1', 'mtracey']},
#  {'text': '@mtracey Go Major @TulsiGabbard !!  #TulsiGabbard #Tulsi2020',
#   'hashtags': ['TulsiGabbard', 'Tulsi2020'],
#   'urls': [],
#   'user_mentions': ['mtracey', 'TulsiGabbard']},
#  {'text': 'RT @mtracey: New qualifying poll for Tulsi in Iowa. She is now *tied* with Kamala and ahead of Booker, Yang, Beto, etc. https://t.co/64yZeu…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['mtracey']},
#  {'text': '@smhforthetruth @realDonaldTrump BITCH !!!   Did you put me on a list???',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['smhforthetruth', 'realDonaldTrump']},
#  {'text': '@briantylercohen @smhforthetruth @realDonaldTrump Technically...  the photographer is.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['briantylercohen', 'smhforthetruth', 'realDonaldTrump']},
#  {'text': '@JustJulie43 @RealCandaceO @TulsiGabbard Explain this then... https://t.co/nm6cbOjAZy',
#   'hashtags': [],
#   'urls': ['https://t.co/nm6cbOjAZy'],
#   'user_mentions': ['JustJulie43', 'RealCandaceO', 'TulsiGabbard']},
#  {'text': "@Trumpmania2020 @RealCandaceO @TulsiGabbard Stop sniffing glue... It's starting to show.",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Trumpmania2020', 'RealCandaceO', 'TulsiGabbard']},
#  {'text': '@wdunlap @RealCandaceO @DavefromFlint @TulsiGabbard WRONG on Open Borders\nWRONG on Late Term Abortion\nWRONG on Univ… https://t.co/mrcCP83Dz5',
#   'hashtags': [],
#   'urls': ['https://t.co/mrcCP83Dz5'],
#   'user_mentions': ['wdunlap',
#    'RealCandaceO',
#    'DavefromFlint',
#    'TulsiGabbard']},
#  {'text': '@JaimeRayon @RealCandaceO @TulsiGabbard I smell an Israeli national...',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['JaimeRayon', 'RealCandaceO', 'TulsiGabbard']},
#  {'text': '@iam_tls @OliviaLaMignon @LLQJ206 @ArenasChristina Your honor,  due to the encounter, the taser gun of the officer… https://t.co/Eq8qdaMUbI',
#   'hashtags': [],
#   'urls': ['https://t.co/Eq8qdaMUbI'],
#   'user_mentions': ['iam_tls',
#    'OliviaLaMignon',
#    'LLQJ206',
#    'ArenasChristina']},
#  {'text': "@Danon_40 @FredTJoseph This nigga doesn't read.  That's obvious.",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Danon_40', 'FredTJoseph']},
#  {'text': '@FredTJoseph @leslieleeiii @Rock_Art_Studio Truly shocking that someone as obtuse as you has almost 40k followers..… https://t.co/FIxiZ6rNAG',
#   'hashtags': [],
#   'urls': ['https://t.co/FIxiZ6rNAG'],
#   'user_mentions': ['FredTJoseph', 'leslieleeiii', 'Rock_Art_Studio']},
#  {'text': '@nikoCSFB @FredTJoseph Fuck this guy...  HRC bootlicker!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['nikoCSFB', 'FredTJoseph']},
#  {'text': '@marciebp @world_hillary @HCullen98 @TulsiGabbard @HillaryClinton Where is my check then??',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['marciebp',
#    'world_hillary',
#    'HCullen98',
#    'TulsiGabbard',
#    'HillaryClinton']},
#  {'text': '@_Lisah @world_hillary @TulsiGabbard @HillaryClinton Bitch... she is at 6% and @HillaryClinton is gonna push her into double digits.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['_Lisah',
#    'world_hillary',
#    'TulsiGabbard',
#    'HillaryClinton',
#    'HillaryClinton']},
#  {'text': '@RedNightOwl @world_hillary @TulsiGabbard @HillaryClinton Yur mom is  Russian bot!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['RedNightOwl',
#    'world_hillary',
#    'TulsiGabbard',
#    'HillaryClinton']},
#  {'text': '@AnayaNKhan Sooooooooo true',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['AnayaNKhan']},
#  {'text': '@BarristerBashan Conversion to Islam is the root cause if truth has to be accepted',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['BarristerBashan']},
#  {'text': '@CMMadhyaPradesh तेओथर तहसील, जिला रीवा, MP, के लेखपाल व तहसील दार सभी दाखिल खारिज फ़ाइल दबा देते हैं और पब्लिक बहु… https://t.co/RqsRWH4uGQ',
#   'hashtags': [],
#   'urls': ['https://t.co/RqsRWH4uGQ'],
#   'user_mentions': ['CMMadhyaPradesh']},
#  {'text': "@ImranKhanPTI You are a dumb man. Wake up. Don't make Pakistani suffer more under Army. Go and commit suside",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ImranKhanPTI']},
#  {'text': '@meherbokhari Madam, I watch your anchoring and I your kinda fan for your professional style. I pray that India and… https://t.co/wYj9xLr9Fe',
#   'hashtags': [],
#   'urls': ['https://t.co/wYj9xLr9Fe'],
#   'user_mentions': ['meherbokhari']},
#  {'text': '@NaelaQuadri Balochistan independence zindabad',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['NaelaQuadri']},
#  {'text': '@NaelaQuadri Madam, if I were th PM of India, I would have give your brave society all physical, emotional, economi… https://t.co/iXTgdSWkhb',
#   'hashtags': [],
#   'urls': ['https://t.co/iXTgdSWkhb'],
#   'user_mentions': ['NaelaQuadri']},
#  {'text': '@BarristerBashan How can he speak when he himself is a nusicance, bigot, liar, puppet and illegal PM in his own cou… https://t.co/LTHmNPUoIT',
#   'hashtags': [],
#   'urls': ['https://t.co/LTHmNPUoIT'],
#   'user_mentions': ['BarristerBashan']},
#  {'text': '@CMOfficeUP बालू के दाम ने सारे रिकॉर्ड तोड़ दिए Sir. मकान कैसे बनवाए?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['CMOfficeUP']},
#  {'text': '@KlasraRauf Answer is obvious. Introspection is needed',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['KlasraRauf']},
#  {'text': '@Huk06 @peaceforchange Asif is a reflection of enormous folly of Acronym called Pakistan',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Huk06', 'peaceforchange']},
#  {'text': '@CMOfficeUP बालू मिल नहीं रही, सावन में रास्ते बंद कर दिए, गिट्टी, सरिया 2 माह नहीं आये गी.. CM जी आप बताए खर्च कैसे चलाये.. हर जगह रोक है..',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['CMOfficeUP']},
#  {'text': '@OfficeOfKNath Save us from NGT order of minor mineral mining as it will kill investment n jobs in biggest employment generator MINING',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['OfficeOfKNath']},
#  {'text': '@PiyushGoyal The greatest sacrifice.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['PiyushGoyal']},
#  {'text': '@gobindahooja @CPResortsGGN Please SOS from builder',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['gobindahooja']},
#  {'text': '@CPResortsGGN Neeraj Agarwal 6A Tower N.. Hello',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': '@ShashiTharoor भाई चुतिया हो क्या',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ShashiTharoor']},
#  {'text': '@ShashiTharoor भाई चुतिया हो क्या',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ShashiTharoor']},
#  {'text': '@KlasraRauf @washingtonpost @nytimes @KlasraRauf please fearlessly show the true position of @pakhtoon tahafus move… https://t.co/uI8GCv1oip',
#   'hashtags': [],
#   'urls': ['https://t.co/uI8GCv1oip'],
#   'user_mentions': ['KlasraRauf',
#    'washingtonpost',
#    'nytimes',
#    'KlasraRauf',
#    'pakhtoon']},
#  {'text': '@KlasraRauf @Muqabil92 @92newschannel Mr Rauf. Please speak on human right abuses in Pakistan',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['KlasraRauf', 'Muqabil92', '92newschannel']},
#  {'text': '@AaronPeskin @TenantsUnionSF @housingrightsSF @SF_CCHO @GavinNewsom @sfbos @SFMTA @Uber @lyft https://t.co/6OK6fZb28z',
#   'hashtags': [],
#   'urls': ['https://t.co/6OK6fZb28z'],
#   'user_mentions': ['AaronPeskin',
#    'TenantsUnionSF',
#    'housingrightsSF',
#    'SF_CCHO',
#    'GavinNewsom',
#    'sfbos',
#    'SFMTA',
#    'Uber',
#    'lyft']},
#  {'text': '@sftwa @GavinNewsom @sfbos @Uber @lyft https://t.co/6OK6fZb28z',
#   'hashtags': [],
#   'urls': ['https://t.co/6OK6fZb28z'],
#   'user_mentions': ['sftwa', 'GavinNewsom', 'sfbos', 'Uber', 'lyft']},
#  {'text': '@sftwa "San Francisco medallions used to be free, granted to drivers after they spent 15 or more years on a waiting… https://t.co/8S7HVjxMxd',
#   'hashtags': [],
#   'urls': ['https://t.co/8S7HVjxMxd'],
#   'user_mentions': ['sftwa']},
#  {'text': '@sftwa https://t.co/nruMsoJLS6',
#   'hashtags': [],
#   'urls': ['https://t.co/nruMsoJLS6'],
#   'user_mentions': ['sftwa']},
#  {'text': '@AaronPeskin @TenantsUnionSF @housingrightsSF @SF_CCHO WHAT ARE YOU DOING TO HELP #SANFRANCISCO CAB DRIVERS?… https://t.co/t1M4vs9LyC',
#   'hashtags': ['SANFRANCISCO'],
#   'urls': ['https://t.co/t1M4vs9LyC'],
#   'user_mentions': ['AaronPeskin',
#    'TenantsUnionSF',
#    'housingrightsSF',
#    'SF_CCHO']},
#  {'text': '@SFCityInsider @EmbarcaderoSafe @DominicFracassa https://t.co/uVDKaYKYDB',
#   'hashtags': [],
#   'urls': ['https://t.co/uVDKaYKYDB'],
#   'user_mentions': ['SFCityInsider', 'EmbarcaderoSafe', 'DominicFracassa']},
#  {'text': "@gavinnewsom @DNC @WSJ @Reuters @cnn please, stop with the #hypocrisy. It's really embarrassing #SanFrancisco &amp;… https://t.co/jhU9nU7PWm",
#   'hashtags': ['hypocrisy', 'SanFrancisco'],
#   'urls': ['https://t.co/jhU9nU7PWm'],
#   'user_mentions': ['GavinNewsom', 'DNC', 'WSJ', 'Reuters', 'CNN']},
#  {'text': '@shamannwalton Just as a reminder of @JUULvapor #contributions to @sfbos &amp; @TheDemocrats @TheMarinaTimes… https://t.co/c37S8tBsTT',
#   'hashtags': ['contributions'],
#   'urls': ['https://t.co/c37S8tBsTT'],
#   'user_mentions': ['shamannwalton',
#    'JUULvapor',
#    'sfbos',
#    'TheDemocrats',
#    'TheMarinaTimes']},
#  {'text': '“(#SanFrancisco Mayor Candidate 2019) @londonbreed is guilty of not only being a puppet of Venture Capitalist Ron C… https://t.co/YqB9sBx3pC',
#   'hashtags': ['SanFrancisco'],
#   'urls': ['https://t.co/YqB9sBx3pC'],
#   'user_mentions': ['LondonBreed']},
#  {'text': 'Acts #racism #classism by @londonbreed? @cnn @WSJ @Sfexaminer @guardian #little @DominicFracassa #SanFrancisco Chri… https://t.co/tzQHdiqv0V',
#   'hashtags': ['racism', 'classism', 'little', 'SanFrancisco'],
#   'urls': ['https://t.co/tzQHdiqv0V'],
#   'user_mentions': ['LondonBreed',
#    'CNN',
#    'WSJ',
#    'sfexaminer',
#    'guardian',
#    'DominicFracassa']},
#  {'text': 'https://t.co/5sVpCmGCnT',
#   'hashtags': [],
#   'urls': ['https://t.co/5sVpCmGCnT'],
#   'user_mentions': []},
#  {'text': '@sfbos @davidchiu @DominicFracassa  "An audience member asked a question targeted Mayor Candidate Breed, who wasn’t… https://t.co/LiV2YukYQY',
#   'hashtags': [],
#   'urls': ['https://t.co/LiV2YukYQY'],
#   'user_mentions': ['sfbos', 'DavidChiu', 'DominicFracassa']},
#  {'text': '@OUTFRONTMEDIAUS Regarding @Ellen4SFMayor billboard in #SanFrancisco? Please, READ &amp; LEARN: https://t.co/IUcR7qwVjK',
#   'hashtags': ['SanFrancisco'],
#   'urls': ['https://t.co/IUcR7qwVjK'],
#   'user_mentions': ['OUTFRONTMEDIAUS', 'Ellen4SFMayor']},
#  {'text': '@EmbarcaderoSafe @MattHaneySF @philmatier @hknightsf https://t.co/IUcR7qwVjK',
#   'hashtags': [],
#   'urls': ['https://t.co/IUcR7qwVjK'],
#   'user_mentions': ['EmbarcaderoSafe',
#    'MattHaneySF',
#    'philmatier',
#    'hknightsf']},
#  {'text': '@EmbarcaderoSafe https://t.co/IUcR7qwVjK',
#   'hashtags': [],
#   'urls': ['https://t.co/IUcR7qwVjK'],
#   'user_mentions': ['EmbarcaderoSafe']},
#  {'text': '@realchrisrufo https://t.co/IUcR7qwVjK',
#   'hashtags': [],
#   'urls': ['https://t.co/IUcR7qwVjK'],
#   'user_mentions': ['realchrisrufo']},
#  {'text': 'https://t.co/rRMeMBBZgd',
#   'hashtags': [],
#   'urls': ['https://t.co/rRMeMBBZgd'],
#   'user_mentions': []},
#  {'text': 'https://t.co/UpnXlUf2JD',
#   'hashtags': [],
#   'urls': ['https://t.co/UpnXlUf2JD'],
#   'user_mentions': []},
#  {'text': "@SFist @LondonBreed @Ellen4SFMayor @KTSF26 @CPASF @sfbos @DavidChiu misdefined @Ellen4SFMayor's billboard as… https://t.co/J33tKMby5U",
#   'hashtags': [],
#   'urls': ['https://t.co/J33tKMby5U'],
#   'user_mentions': ['SFist',
#    'LondonBreed',
#    'Ellen4SFMayor',
#    'KTSF26',
#    'CPASF',
#    'sfbos',
#    'DavidChiu',
#    'Ellen4SFMayor']},
#  {'text': '@SFist @LondonBreed "Never make fun of someone who speaks broken English. It means they know another language." H.… https://t.co/xBgnMsjyBL',
#   'hashtags': [],
#   'urls': ['https://t.co/xBgnMsjyBL'],
#   'user_mentions': ['SFist', 'LondonBreed']},
#  {'text': '@dogfather Happy birthday and thank you for your rates!!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['dogfather']},
#  {'text': '@chriscolfer Cannot wait to start reading this with my 9 year old. She is going to be so excited!! #ATaleOfMagic #LandofStories',
#   'hashtags': ['ATaleOfMagic', 'LandofStories'],
#   'urls': [],
#   'user_mentions': ['chriscolfer']},
#  {'text': '@HowToBeARedhead Mascara!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['HowToBeARedhead']},
#  {'text': '@8bitpimp Doesn’t Paris have its own chocolate? 🤪 #funnynotfunny',
#   'hashtags': ['funnynotfunny'],
#   'urls': [],
#   'user_mentions': ['8bitpimp']},
#  {'text': '@Stemage So bummed to miss this one!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Stemage']},
#  {'text': "RT @Stemage: So hype for this! If you're at SDCC, come to the Vince DiCola show! https://t.co/A2HXu5Ztal",
#   'hashtags': [],
#   'urls': ['https://t.co/A2HXu5Ztal'],
#   'user_mentions': ['Stemage']},
#  {'text': '@PTXofficial @disneylionking OMGinger! The key changes, Mitch in the stratosphere, takes me right on back to the or… https://t.co/dWyijjBCGy',
#   'hashtags': [],
#   'urls': ['https://t.co/dWyijjBCGy'],
#   'user_mentions': ['PTXofficial', 'disneylionking']},
#  {'text': '@nalrog @DiColaOfficial #legit',
#   'hashtags': ['legit'],
#   'urls': [],
#   'user_mentions': ['nalrog', 'DiColaOfficial']},
#  {'text': '@8bitpimp #blenderanimation https://t.co/aC4vs1wTVF',
#   'hashtags': ['blenderanimation'],
#   'urls': ['https://t.co/aC4vs1wTVF'],
#   'user_mentions': ['8bitpimp']},
#  {'text': '@8bitpimp ‼️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['8bitpimp']},
#  {'text': '@PTXofficial @benhausdo Loved every minute of it! You packed so much great music in!! Favorite moment though... #TheSoundofSilence 💜💙❤️💛💚',
#   'hashtags': ['TheSoundofSilence'],
#   'urls': [],
#   'user_mentions': ['PTXofficial', 'benhausdo']},
#  {'text': 'And the #ultimate @PTXofficial !!! Thanks for the show@💜🤘🏻🤟🏻 https://t.co/c5lHVpoRbB',
#   'hashtags': ['ultimate'],
#   'urls': ['https://t.co/c5lHVpoRbB'],
#   'user_mentions': ['PTXofficial']},
#  {'text': '@RachelPlatten so inspirational!! #fightsong #youbelong https://t.co/eRSnbekAGJ',
#   'hashtags': ['fightsong', 'youbelong'],
#   'urls': ['https://t.co/eRSnbekAGJ'],
#   'user_mentions': ['RachelPlatten']},
#  {'text': '@CQOfficial slayed!!! https://t.co/CimeJCGeaL',
#   'hashtags': [],
#   'urls': ['https://t.co/CimeJCGeaL'],
#   'user_mentions': ['CQOfficial']},
#  {'text': '@ptxofficial WE. ARE. READY. BRING ON THE MUSIC!!!! @ Tacoma Dome https://t.co/JpToQHqe2B',
#   'hashtags': [],
#   'urls': ['https://t.co/JpToQHqe2B'],
#   'user_mentions': ['PTXofficial']},
#  {'text': '@megabeardo SEA AT TLE #tourstop',
#   'hashtags': ['tourstop'],
#   'urls': [],
#   'user_mentions': ['megabeardo']},
#  {'text': '@chrissyteigen !!!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['chrissyteigen']},
#  {'text': '@theheleneugene ❣️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['theheleneugene']},
#  {'text': '@MichelleLiTV @JimVanDillen Feel better soon!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['MichelleLiTV', 'JimVanDillen']},
#  {'text': '@HowToBeARedhead I tell people I get sunburned just thinking about the sun!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['HowToBeARedhead']},
#  {'text': 'RT @LulaFortune4: This is f**ing great. Her face is the best part 😂 https://t.co/AvESs68lzY',
#   'hashtags': [],
#   'urls': ['https://t.co/AvESs68lzY'],
#   'user_mentions': ['LulaFortune4']},
#  {'text': 'RT @EvanAKilgore: A 7-year-old boy will be "transitioned" into a girl with hormone blockers and sex change hormones after his mother decide…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['EvanAKilgore']},
#  {'text': 'RT @DuaneBratt: Trudeau is leading a govt, who lost the popular vote, and facing a resurgent Bloc and outraged AB/SK. He is going to have t…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['DuaneBratt']},
#  {'text': "RT @PrisonPlanet: Congratulations to Justin Trudeau, world's number 1 blackface enthusiast, on his election success.\n\nYet more proof that p…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['PrisonPlanet']},
#  {'text': 'RT @votejkent: Friends, please vote in this poll. \n\nWho are you voting for tomorrow? Please retweet to get a larger sample. #CDNpoli #Elxn4…',
#   'hashtags': ['CDNpoli'],
#   'urls': [],
#   'user_mentions': ['votejkent']},
#  {'text': 'RT @HarveyMyatt: Friends, I just heard fr Mr. Manny!\nHe is ok. \nTHANK GOD 🙏\nThis most important!!\nHe was banned 4 few days.\nShame on you @T…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['HarveyMyatt']},
#  {'text': "RT @Franktmcveety: Let's be clear: No one holds veto power over our right to develop our resources. If B.C.and Quebec don’t want to work wi…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Franktmcveety']},
#  {'text': 'RT @Yukon_Strong: I’m not from the dark corners of the web. \n\nI’m born and raised in the bush. Hunted, trapped, fished, and sh*t kicked my…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Yukon_Strong']},
#  {'text': 'RT @AngusReid: The feelings in the West are part of what psychologists call the “frustration-Aggression” complex. Most people in CDN still…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['AngusReid']},
#  {'text': 'RT @SundanceConstr1: Brilliant display. So many are not thinking long-term. https://t.co/N88p6JDKHC',
#   'hashtags': [],
#   'urls': ['https://t.co/N88p6JDKHC'],
#   'user_mentions': ['SundanceConstr1']},
#  {'text': 'RT @allsystemsjo: Greta Thunberg: hey guys I’m Greta let’s maybe transition to some greener energy so there’s still a world for me to grow…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['allsystemsjo']},
#  {'text': "RT @Donnydad: If anyone plans on protesting Greta's presence, show that we are adults. \nThis is an obvious setup to paint Alberta in a bad…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Donnydad']},
#  {'text': '@TomEngel18 @teesix Fuck you Trevor',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TomEngel18', 'teesix']},
#  {'text': 'RT @Franktmcveety: Only a broken-down, demoralized and aimless Leader would park his bus in front of a Whitby strip club. Clueless.\n\n#Notas…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Franktmcveety']},
#  {'text': "RT @fordnation: Here's what I think about phones in class 👇 https://t.co/4PKYVb4Pep",
#   'hashtags': [],
#   'urls': ['https://t.co/4PKYVb4Pep'],
#   'user_mentions': ['fordnation']},
#  {'text': 'RT @PipelineAction: “...Norway last week switched on a massive new oil project that will operate for 50 years, to 2069 (that’s 39 years aft…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['PipelineAction']},
#  {'text': '@JaminAgain These ladies seem to be frustrated, can you give them chores like milking a cow twice a day by hand.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['JaminAgain']},
#  {'text': 'RT @Bzubyk: The exact right answer by Scheer. \n\nI’m not interested in what ex foreign leaders are saying. I’m focused on what Canadians are…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Bzubyk']},
#  {'text': 'RT @mikelecouteur: CPC leader @AndrewScheer on former US president @BarackObama’s endorsement of @JustinTrudeau \n#cdnpoli #elxn43 @GlobalNa…',
#   'hashtags': ['cdnpoli', 'elxn43'],
#   'urls': [],
#   'user_mentions': ['mikelecouteur',
#    'AndrewScheer',
#    'BarackObama',
#    'JustinTrudeau']},
#  {'text': '@FinsUpSailor @Wowk67 There has to be a money trail from Trudope to these fools',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['FinsUpSailor', 'Wowk67']}]

# %% [markdown]
# [NLTK Stopwords](https://pythonspot.com/nltk-stop-words/)

# %%
STOPWORDS = stopwords.words('english')
# TODO: decide whether or not to remove tweets that are from retweets altogether
more_stop_words = ['rt']
STOPWORDS.extend(more_stop_words)
STOPWORDS
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'rt']

# %%
def word_extraction(tweet_dictionary, stopwords = STOPWORDS):  
    sentence = tweet_dictionary['text']
    hashtags = ['#' + s for s in tweet_dictionary['hashtags']]
    urls = tweet_dictionary['urls']
    user_mentions = ['@' + s for s in tweet_dictionary['user_mentions']]
    
    ignore = hashtags + urls + user_mentions

    words = sentence.split()  
    
    cleaned_text = []
    
    for word in words:
        cleaned_word = re.sub("[^\w]", "",  word)
        if (not word in ignore) and (not word.lower() in stopwords) and (word.isalpha()) and (len(cleaned_word) > 0):
            cleaned_text.append(cleaned_word.lower())
    return cleaned_text

# %%
test_tweet = tweets_data[len(tweets_data)-1]
print(word_extraction(test_tweet))
print(test_tweet)
# Out:
# ['money', 'trail', 'trudope', 'fools']
# {'text': '@FinsUpSailor @Wowk67 There has to be a money trail from Trudope to these fools', 'hashtags': [], 'urls': [], 'user_mentions': ['FinsUpSailor', 'Wowk67']}

# %%
tweets_text = []
for tweet in tweets_data:
    tweets_text.extend(word_extraction(tweet))
print("Extracted words:", tweets_text)
# Out:
# Extracted words: ['good', 'deed', 'goes', 'like', 'ones', 'include', 'description', 'suspect', 'might', 'helpful', 'residents', 'two', 'large', 'cups', 'dark', 'caffeine', 'finally', 'starting', 'kick', 'home', 'right', 'protect', 'family', 'playing', 'elevate', 'keep', 'brain', 'think', 'like', 'get', 'thank', 'talk', 'super', 'bowl', 'titles', 'greta', 'thunberg', 'speaks', 'un', 'climate', 'come', 'us', 'young', 'people', 'dare', 'read', 'heroic', 'bystanders', 'rescue', 'girl', 'father', 'dies', 'jumping', 'front', 'subway', 'train', 'abc', 'news', 'via', 'trinity', 'lawrence', 'student', 'name', 'login', 'order', 'please', 'help', 'support', 'grapevine', 'middle', 'school', 'please', 'support', 'rae', 'texas', 'end', 'road', 'many', 'louisiana', 'state', 'friday', 'explores', 'key', 'oh', 'live', 'beto', 'keene', 'state', 'early', 'bird', 'gets', 'cowboys', 'golf', 'club', 'donald', 'latest', 'conspiracy', 'theory', 'fox', 'yasssss', 'first', 'last', 'time', 'house', 'horrors', 'literally', 'best', 'friend', 'baby', 'lonestar', 'antiques', 'dick', 'would', 'get', 'better', 'committee', 'btw', 'fix', 'statement', 'like', 'republicans', 'native', 'americans', 'north', 'south', 'soon', 'interesting', 'defense', 'continue', 'admit', 'maybe', 'gonna', 'admitted', 'republican', 'colleagues', 'everyone', 'else', 'today', 'constitutional', 'duties', 'diplomat', 'two', 'words', 'sean', 'hannity', 'washington', 'dc', 'tonight', 'kurdish', 'people', 'look', 'stars', 'northern', 'many', 'big', 'decisions', 'zero', 'doubt', 'going', 'texts', 'testimony', 'make', 'clear', 'president', 'using', 'administration', 'confirmed', 'today', 'turkey', 'ignored', 'warning', 'blinked', 'withdrawing', 'troops', 'catastrophic', 'outcome', 'trying', 'spin', 'filled', 'isis', 'fighters', 'favorite', 'part', 'whole', 'affair', 'today', 'long', 'slow', 'divorce', 'republican', 'party', 'rule', 'law', 'obviously', 'important', 'country', 'removed', 'office', 'extraordinary', 'corrupt', 'think', 'house', 'hearings', 'grand', 'ever', 'heard', 'grand', 'jury', 'letting', 'cerebral', 'palsy', 'wanted', 'skate', 'board', 'mom', 'created', 'heart', 'mother', 'chief', 'staff', 'admitted', 'military', 'aid', 'withheld', 'ally', 'get', 'help', 'trump', 'sought', 'personal', 'favor', 'exchange', 'official', 'act', 'releasing', 'million', 'work', 'republicans', 'congress', 'might', 'believe', 'majority', 'americans', 'one', 'law', 'follow', 'tulsi', 'gabbard', 'video', 'via', 'propagandist', 'get', 'change', 'go', 'major', 'new', 'qualifying', 'poll', 'tulsi', 'kamala', 'ahead', 'bitch', 'put', 'photographer', 'explain', 'stop', 'sniffing', 'starting', 'wrong', 'open', 'borders', 'wrong', 'late', 'term', 'abortion', 'wrong', 'smell', 'israeli', 'due', 'taser', 'gun', 'nigga', 'truly', 'shocking', 'someone', 'obtuse', 'almost', 'fuck', 'hrc', 'check', 'gonna', 'push', 'double', 'yur', 'mom', 'russian', 'sooooooooo', 'true', 'conversion', 'islam', 'root', 'cause', 'truth', 'accepted', 'व', 'और', 'dumb', 'wake', 'make', 'pakistani', 'suffer', 'go', 'commit', 'suside', 'watch', 'anchoring', 'kinda', 'fan', 'professional', 'pray', 'india', 'balochistan', 'independence', 'zindabad', 'th', 'pm', 'would', 'give', 'brave', 'society', 'speak', 'puppet', 'illegal', 'pm', 'answer', 'introspection', 'needed', 'asif', 'reflection', 'enormous', 'folly', 'acronym', 'called', 'pakistan', 'कर', 'cm', 'आप', 'हर', 'जगह', 'save', 'us', 'ngt', 'order', 'minor', 'mineral', 'mining', 'kill', 'investment', 'n', 'jobs', 'biggest', 'employment', 'generator', 'mining', 'greatest', 'please', 'sos', 'builder', 'neeraj', 'agarwal', 'tower', 'hello', 'please', 'fearlessly', 'show', 'true', 'position', 'tahafus', 'mr', 'please', 'speak', 'human', 'right', 'abuses', 'pakistan', 'francisco', 'medallions', 'used', 'granted', 'drivers', 'spent', 'years', 'help', 'cab', 'stop', 'really', 'embarrassing', 'reminder', 'mayor', 'candidate', 'guilty', 'puppet', 'venture', 'capitalist', 'ron', 'acts', 'audi ...

# %%
tweets_hashtags = []
for tweet in tweets_data:
        tweets_hashtags.extend(tweet['hashtags'])
print("Extracted hashtags:", tweets_hashtags)
# Out:
# Extracted hashtags: ['Classic', 'JubHawk', 'JubHawk', 'jubhawk2019', 'fish', 'liveyourbestlife', 'miniaussie', 'catfishingnation', 'sundayfunday', 'hangmanshouseofhorrors', 'imababy', 'halloween', 'throwback', 'love', 'LockThemUp', 'Tulsi2020', 'TulsiGabbard', 'Tulsi2020', 'SANFRANCISCO', 'hypocrisy', 'SanFrancisco', 'contributions', 'SanFrancisco', 'racism', 'classism', 'little', 'SanFrancisco', 'SanFrancisco', 'ATaleOfMagic', 'LandofStories', 'funnynotfunny', 'legit', 'blenderanimation', 'TheSoundofSilence', 'ultimate', 'fightsong', 'youbelong', 'tourstop', 'CDNpoli', 'cdnpoli', 'elxn43']

# %%
def get_freq_map(my_list): 
    freq = {} 
    for item in my_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
    return freq

def get_top_freq(my_list, top_count):
    freq = get_freq_map(my_list)
    freq = sorted(freq.items(), key=lambda item: item[1], reverse = True)
    
    if len(freq) <= top_count:
        return freq
    else:
        return freq[:10]

# %%
tweets_text_freq = get_top_freq(tweets_text, WORD_FREQ_LIMIT)
print("TOP {0} most freq words".format(WORD_FREQ_LIMIT))
tweets_text_freq
# Out:
# get top most freq words
# [('please', 7),
#  ('get', 6),
#  ('right', 5),
#  ('like', 4),
#  ('people', 4),
#  ('think', 3),
#  ('thank', 3),
#  ('greta', 3),
#  ('us', 3),
#  ('help', 3)]

# %%
tweets_hashtags_freq = get_top_freq(tweets_hashtags, 10)
tweets_hashtags_freq
# Out:
# [('SanFrancisco', 4),
#  ('JubHawk', 2),
#  ('Tulsi2020', 2),
#  ('Classic', 1),
#  ('jubhawk2019', 1),
#  ('fish', 1),
#  ('liveyourbestlife', 1),
#  ('miniaussie', 1),
#  ('catfishingnation', 1),
#  ('sundayfunday', 1)]
