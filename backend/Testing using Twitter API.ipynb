# %%
# %%capture
try:
    from pip import main as pipmain
except:
    from pip._internal import main as pipmain
packages = ['twython']
pipmain(['install'] + packages)

# %%
# %%capture
from twython import Twython

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')

import re
import random

# %%
from auth import (
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)

twitter = Twython(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)

# %%
PRINT_LIMIT = 50
FOLLOWER_SAMPLE_LIMIT = 20 # number of followers to randomly sample
WORD_FREQ_LIMIT = 10 # return this number of topics that are most freq

# %%
user = "AndrewYang"

# %%
followers = twitter.get_followers_ids(screen_name = user)

limit = 0
for follower_id in followers['ids']:
    print('Follower Id: {0} '.format(follower_id))
    limit += 1
    if limit >= PRINT_LIMIT:
        break
# Out:
# Follower Id: 1066754695912349696
# Follower Id: 3094679364
# Follower Id: 4898817859
# Follower Id: 1046973263652499456
# Follower Id: 826279704764125184
# Follower Id: 56789243
# Follower Id: 1025216100718583809
# Follower Id: 1187231128282947584
# Follower Id: 2206178504
# Follower Id: 2811529981
# Follower Id: 2214471943
# Follower Id: 1187230717215940610
# Follower Id: 2361794225
# Follower Id: 2460219890
# Follower Id: 1187227948199370752
# Follower Id: 728381963761917952
# Follower Id: 991509045101056000
# Follower Id: 314851797
# Follower Id: 1187094020624977920
# Follower Id: 1115134837
# Follower Id: 1168595858516074498
# Follower Id: 2682096483
# Follower Id: 761434193993854976
# Follower Id: 922107187
# Follower Id: 1180084653979586562
# Follower Id: 841037012
# Follower Id: 2377608512
# Follower Id: 1187228886834257920
# Follower Id: 835799316
# Follower Id: 1618391833
# Follower Id: 454538051
# Follower Id: 2381104249
# Follower Id: 14817882
# Follower Id: 1017675294830878720
# Follower Id: 1166857532138299393
# Follower Id: 920870303227559936
# Follower Id: 3378486460
# Follower Id: 1187226972214222849
# Follower Id: 1183159773262303232
# Follower Id: 993728474148843520
# Follower Id: 1183590936493735936
# Follower Id: 2400409873
# Follower Id: 1185318366124265473
# Follower Id: 255830445
# Follower Id: 2386477038
# Follower Id: 960238320533073920
# Follower Id: 75938423
# Follower Id: 889245999721361408
# Follower Id: 721465654868455425
# Follower Id: 1177946965943967744

# %%
def get_tweet_data(results):
    tweets = []
    for tweet in results:
        tweet_map = {"text": tweet['text']}
        tweet_hashtags = []
        tweet_urls = []
        tweet_user_mentions = []
        
        entities = tweet['entities']
    
        for hashtags in entities['hashtags']:
            tweet_hashtags.append(hashtags['text'])
        for urls in entities['urls']:
            tweet_urls.append(urls['url'])
        try:
            for media in entities['media']:
                tweet_urls.append(media['url'])
        except:
            pass
        for users in entities['user_mentions']:
            tweet_user_mentions.append(users['screen_name'])
            
        tweet_map["hashtags"] = tweet_hashtags
        tweet_map["urls"] = tweet_urls
        tweet_map["user_mentions"] = tweet_user_mentions
        tweets.append(tweet_map)
        
    return tweets

# %%
def get_tweets_data_from(user_id, results):
    try: 
        result = twitter.get_user_timeline(user_id = user_id)
        results.extend(result)
        return get_tweet_data(result), results
    except:
        return [], results

# %%
def get_tweets_data_and_results(user_ids):
    tweets_data = []
    results = []
    
    samples = user_ids
    if len(user_ids) > FOLLOWER_SAMPLE_LIMIT:
        samples = random.sample(user_ids, FOLLOWER_SAMPLE_LIMIT)

    for f in samples:
        result, results = get_tweets_data_from(f, results)
        tweets_data.extend(result)
            
    return tweets_data, results
    
tweets_data, results = get_tweets_data_and_results(followers['ids'])

# %%
tweets_data
# Out:
# [{'text': 'RT @utahjazz: All-Star is coming back to SLC in 2023 ❄️🏀🌟 https://t.co/yHaX78p8Id',
#   'hashtags': [],
#   'urls': ['https://t.co/yHaX78p8Id'],
#   'user_mentions': ['utahjazz']},
#  {'text': '@jazzteamstore @dalystexxxas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jazzteamstore', 'dalystexxxas']},
#  {'text': 'RT @jazzteamstore: ⚡️TICKET GIVEAWAY⚡️\nWe’re giving away 2 tickets to tonight’s home opener vs. Oklahoma City Thunder!\n\nTo Enter:\n1️⃣Follow…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jazzteamstore']},
#  {'text': '@MLozada 😡',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['MLozada']},
#  {'text': 'RT @summit1g: Giveaway time! Corsair hitting someone up with a new K70 MK.2 SE\n\nTo Enter: \n- Retweet and Like this post\n- Follow @Summit1G…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['summit1g', 'summit1g']},
#  {'text': '@vivintarena @utahjazz @trailblazers @dalystexxxas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['vivintarena',
#    'utahjazz',
#    'trailblazers',
#    'dalystexxxas']},
#  {'text': "RT @vivintarena: FLASH GIVEAWAY: Win 4 tickets to tonight's @utahjazz vs @trailblazers preseason game and $80 for dinner at Hires Big H in…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['vivintarena', 'utahjazz', 'trailblazers']},
#  {'text': '@jazzteamstore @vivintarena @utahjazz @dalystexxxas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jazzteamstore',
#    'vivintarena',
#    'utahjazz',
#    'dalystexxxas']},
#  {'text': 'RT @jazzteamstore: ⚡️TICKET GIVEAWAY⚡️\nWe’re giving away 2 tickets to tonight’s preseason game vs. Sacramento Kings!\n\nTo Enter:\n1️⃣Follow @…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jazzteamstore']},
#  {'text': 'RT @drdisrespect: Fortnite is gone.\n\nI couldn’t be more happier.   \n\nDemonized children will turn back to normal 8th graders. The gaming in…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['drdisrespect']},
#  {'text': 'RT @pulte: I’ll give $11,000 to someone random who retweets this, and yes, I will pay it ✅ (must be following so I can dm you, 18+, ends 56…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['pulte']},
#  {'text': '@vivintarena @utahjazz @SacramentoKings @dalystexxxas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['vivintarena',
#    'utahjazz',
#    'SacramentoKings',
#    'dalystexxxas']},
#  {'text': 'RT @vivintarena: GIVEAWAY: Win 4 tickets to the @utahjazz vs. @SacramentoKings preseason game on Monday October 14 and $80 for dinner at Ma…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['vivintarena', 'utahjazz', 'SacramentoKings']},
#  {'text': 'RT @AngelaGordiano8: If you guys could please help and donate or even retweet this tweet thank you ! https://t.co/D9syP8s19H',
#   'hashtags': [],
#   'urls': ['https://t.co/D9syP8s19H'],
#   'user_mentions': ['AngelaGordiano8']},
#  {'text': 'RT @diegosaurs_: I’ve been enjoying season 3 of apex a lot so far. If any of you don’t have the battlepass yet, then check this out. @TSM a…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['diegosaurs_', 'TSM']},
#  {'text': 'RT @pulte: I’ll give $4,999 CASH to someone random who retweets this because it’s a Beautiful Afternoon 🤗 (must be following so I can dm yo…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['pulte']},
#  {'text': '@vivintarena @utahjazz @dalystexxxas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['vivintarena', 'utahjazz', 'dalystexxxas']},
#  {'text': 'RT @vivintarena: The boys are back at #VivintArena tomorrow! \nWin 4 suite tickets to the first @utahjazz preseason game and $80 for dinner…',
#   'hashtags': ['VivintArena'],
#   'urls': [],
#   'user_mentions': ['vivintarena', 'utahjazz']},
#  {'text': 'RT @Sethlyy: Season 3 Battle Pass Giveaway! (5 Winners / Announced in 7 Days)\nHow to enter:\n1. Retweet This Tweet\n2. Must be following @Set…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Sethlyy']},
#  {'text': 'RT @pulte: I’ll give $11,000 to someone random who retweets this, and yup I do pay these 💵 (must be following so I can dm you, 18+, rules:…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['pulte']},
#  {'text': '@wayneidoyle Congrats!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['wayneidoyle']},
#  {'text': '@XiangLi59264116 @emukamel @wayneidoyle 😂',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['emukamel', 'wayneidoyle']},
#  {'text': '@LukeUlatowski hell ya you tell em lucas',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['LukeUlatowski']},
#  {'text': "so my phone's lcd broke/cracked but the glass is fine, didn't drop it or hit it, just unlocked it and it's suddenly… https://t.co/gLnvOhCTUP",
#   'hashtags': [],
#   'urls': ['https://t.co/gLnvOhCTUP'],
#   'user_mentions': []},
#  {'text': 'are we thinking of the same game https://t.co/zhDO9i1nzt',
#   'hashtags': [],
#   'urls': ['https://t.co/zhDO9i1nzt'],
#   'user_mentions': []},
#  {'text': 'so my cat learned how to open doors',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'every year i get closer to ditching the iphone for the pixel...but imessage',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': '@jaredkim @LepWho @LukeUlatowski im feeling lucky and cant wait to brag to you',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jaredkim', 'LepWho', 'LukeUlatowski']},
#  {'text': 'RT @jaredkim: I’m going to give away another GeForce RTX 2080 Ti for your weekend of gaming. \n\nINSTRUCTIONS TO ENTER:\n💜 Retweet this\n💜 Foll…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['jaredkim']},
#  {'text': 'a beautiful day for some stardew valley',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @Pokemon: Halloween Impact:\n\n         █\n         █          \u3000\u3000\n         █          \u3000\u3000         \u3000\u3000\n         █…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Pokemon']},
#  {'text': 'RT @PlayStation: PlayStation 5 launches holiday 2020: https://t.co/VuaxUVoBaR #PS5 https://t.co/MPkKyRaHio',
#   'hashtags': ['PS5'],
#   'urls': ['https://t.co/VuaxUVoBaR', 'https://t.co/MPkKyRaHio'],
#   'user_mentions': ['PlayStation']},
#  {'text': 'wow i, tasha, am trending thanks guys',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @IansMadison: It’s #FreePizzaFriday! Retweet this tweet and you’ll be entered to win 8 free slice cards! \n\nReady…. Set….. Retweet! \n\nWe’…',
#   'hashtags': ['FreePizzaFriday'],
#   'urls': [],
#   'user_mentions': ['IansMadison']},
#  {'text': 'RT @waasabbi: “He’s probably out cheating right now🤬😡” \n\nHim: https://t.co/m1cpQjoiwD',
#   'hashtags': [],
#   'urls': ['https://t.co/m1cpQjoiwD'],
#   'user_mentions': ['waasabbi']},
#  {'text': 'i changed my fb profile pic to an older picture bc why not i liked it, but my parents thought it was just taken. as… https://t.co/leNDyRMqO9',
#   'hashtags': [],
#   'urls': ['https://t.co/leNDyRMqO9'],
#   'user_mentions': []},
#  {'text': 'i dont think my favorite noodles employee works here anymore i miss him',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @Neil_Druckmann: Tick... Tick... Click...\n\nSee you tomorrow. https://t.co/yR7QJbaRnc',
#   'hashtags': [],
#   'urls': ['https://t.co/yR7QJbaRnc'],
#   'user_mentions': ['Neil_Druckmann']},
#  {'text': "kinda rude that it'd cost me a whole grand to meet chris hemsworth and tom holland at comic con but they're sold ou… https://t.co/1GloAl4rWP",
#   'hashtags': [],
#   'urls': ['https://t.co/1GloAl4rWP'],
#   'user_mentions': []},
#  {'text': 'lmao the person who delivered my uber eats literally ate half of it??',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @istifhan: Too much chocolate is disgusting man 🤢 https://t.co/Y7nWTlnv9p',
#   'hashtags': [],
#   'urls': ['https://t.co/Y7nWTlnv9p'],
#   'user_mentions': ['istifhan']},
#  {'text': "RT @CBCAlerts: Polls have opened for the 1st voters in Canada's 43rd general election. Polling stations went into operation on the island o…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['CBCAlerts']},
#  {'text': "“The discussion about whether photography is or isn't art is dated and of no interest. Your work makes you an artis… https://t.co/zvEcDZfttd",
#   'hashtags': [],
#   'urls': ['https://t.co/zvEcDZfttd'],
#   'user_mentions': []},
#  {'text': 'RT @deric_tv: Wk3 &amp; the Amazon Forest continues to burn with thousands of hectares of forestry &amp; habitats destroyed FYI: it produces 20% of…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['deric_tv']},
#  {'text': 'I’ve never felt as vulnerable and nervous as I did today.  During today’s the @TheArtOf Leadership Conference I ask… https://t.co/CbLPJ1ZDtp',
#   'hashtags': [],
#   'urls': ['https://t.co/CbLPJ1ZDtp'],
#   'user_mentions': ['TheArtOf']},
#  {'text': "Over the past couple of years I have really fallen in love with the VLOG format.  It's so much more fun than regula… https://t.co/J9HmSdIcau",
#   'hashtags': [],
#   'urls': ['https://t.co/J9HmSdIcau'],
#   'user_mentions': []},
#  {'text': '🎅🏻 Please dig up the quarters and dimes from that gap in your couch and pop by @PHOTOBOXvan for our Downtown Eastsi… https://t.co/hYQqpNYXw6',
#   'hashtags': [],
#   'urls': ['https://t.co/hYQqpNYXw6'],
#   'user_mentions': []},
#  {'text': 'Congrats @valmontcosmetic on the opening of the first NA boutique at Oakridge Centre! @Oakridgestyle @VancouverSun https://t.co/M6XbizDZzY',
#   'hashtags': [],
#   'urls': ['https://t.co/M6XbizDZzY'],
#   'user_mentions': ['valmontcosmetic', 'Oakridgestyle', 'VancouverSun']},
#  {'text': "Phew~ that's a lot of pics!  https://t.co/j7opBOUlzU #photographer #vancouverprofessional #canadianphotographer https://t.co/Hz8ZpVcQWP",
#   'hashtags': ['photographer',
#    'vancouverprofessional',
#    'canadianphotographer'],
#   'urls': ['https://t.co/j7opBOUlzU', 'https://t.co/Hz8ZpVcQWP'],
#   'user_mentions': []},
#  {'text': "It's going to be a busy Summer!  Getting organized feels great! :) #photographer #vancouverprofessional",
#   'hashtags': ['photographer', 'vancouverprofessional'],
#   'urls': [],
#   'user_mentions': []},
#  {'text': "Big Congratulations on the @TheJUNOAwards nomination @wdflandez! Great interview in and spread in today's… https://t.co/1wviaPeYQD",
#   'hashtags': [],
#   'urls': ['https://t.co/1wviaPeYQD'],
#   'user_mentions': ['TheJUNOAwards', 'wdflandez']},
#  {'text': 'PHOTOBOX has arrived! It was so great to see you all! #vancouverbusiness #photoboxvancouver #vancouverevent… https://t.co/UhyLlmYp4E',
#   'hashtags': ['vancouverbusiness', 'photoboxvancouver', 'vancouverevent'],
#   'urls': ['https://t.co/UhyLlmYp4E'],
#   'user_mentions': []},
#  {'text': 'Excited to announce the opening of my photography studio in the heart of DT #Vancouver! RSVP:info@widejko.com… https://t.co/KhB3xFwvkE',
#   'hashtags': ['Vancouver'],
#   'urls': ['https://t.co/KhB3xFwvkE'],
#   'user_mentions': []},
#  {'text': 'Happy Holidays everyone!  Much 💗 and all good things for the New Year!  🎄🙏💫 #happyholidays https://t.co/wxaIWtI9qh',
#   'hashtags': ['happyholidays'],
#   'urls': ['https://t.co/wxaIWtI9qh'],
#   'user_mentions': []},
#  {'text': "RT @Upworthy: Before Rosa Parks, there was Viola Desmond. She's the new face of Canada's $10 bill. https://t.co/tuRY0eQzQI https://t.co/c0j…",
#   'hashtags': [],
#   'urls': ['https://t.co/tuRY0eQzQI'],
#   'user_mentions': ['Upworthy']},
#  {'text': 'BTS from BG Canada photo shoot.  #vancouverphotography #photographer #vancovuerfashion https://t.co/uk7UgJ9CfA',
#   'hashtags': ['vancouverphotography', 'photographer', 'vancovuerfashion'],
#   'urls': ['https://t.co/uk7UgJ9CfA'],
#   'user_mentions': []},
#  {'text': 'RT @karolynhaze: Super fun session with @widejko widejkophotography widejkoportrait #photoshoot #photography… https://t.co/C4NgvBP3kY',
#   'hashtags': ['photoshoot', 'photography'],
#   'urls': ['https://t.co/C4NgvBP3kY'],
#   'user_mentions': ['karolynhaze', 'WIDEJKO']},
#  {'text': 'The little black dress! Portraits on sale at $50-$100OFF until Jan 15, 2017 #vancouver #vancouverbusiness… https://t.co/0k9sbWQTyj',
#   'hashtags': ['vancouver', 'vancouverbusiness'],
#   'urls': ['https://t.co/0k9sbWQTyj'],
#   'user_mentions': []},
#  {'text': '&lt;3 shooting this project for Karma Athletics! @MetropolisatMet @karmaathletics_ #activewear #lookbook… https://t.co/I8BI7tNiWH',
#   'hashtags': ['activewear', 'lookbook'],
#   'urls': ['https://t.co/I8BI7tNiWH'],
#   'user_mentions': ['MetropolisatMet', 'karmaathletics_']},
#  {'text': '"A witty woman is a treasure; a witty beauty is a power"\nSuch pleasure capturing this beauty #vancouverprofessional… https://t.co/jFJFLeS1nn',
#   'hashtags': ['vancouverprofessional'],
#   'urls': ['https://t.co/jFJFLeS1nn'],
#   'user_mentions': []},
#  {'text': 'Three assignments tomorrow, wish me luck! #busybusy',
#   'hashtags': ['busybusy'],
#   'urls': [],
#   'user_mentions': []},
#  {'text': '@TonySlayor Where u at?!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': 'RT @TonySlayor: Can’t wait to stream tonight Slayors! I’m so excited, I may get on early... I’ll keep ya posted!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': 'RT @TonySlayor: I can’t wait to stream tonight Slayors! Twitch rolled out this new Stream Manager feature that’s going to be extremely help…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor I can for sure! FYI doesn’t look like your package is going to arrive until Friday. Not sure if you’re going to be around',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor Was a short one? Didn’t think you were streaming today',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor Yes! I’ll be waiting with a shot ready to go! Btw your pickles are shipping today. I’ll dm you the tracking #',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor Nice!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor @ScufGaming Aweee shiii...',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor', 'ScufGaming']},
#  {'text': '@Phixate @EA_DICE @Battlefield https://t.co/5mSrb5uq6G',
#   'hashtags': [],
#   'urls': ['https://t.co/5mSrb5uq6G'],
#   'user_mentions': ['Phixate', 'EA_DICE', 'Battlefield']},
#  {'text': "RT @Phixate: There's only one thing @EA_DICE should be focusing on to help revitalize the great game of @Battlefield V \n#MakeFirestormFree",
#   'hashtags': ['MakeFirestormFree'],
#   'urls': [],
#   'user_mentions': ['Phixate', 'EA_DICE', 'Battlefield']},
#  {'text': '@TonySlayor I don’t wanna hear about your bowl situation. - Tony Slayor',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@TonySlayor https://t.co/5KBmiVWk8S',
#   'hashtags': [],
#   'urls': ['https://t.co/5KBmiVWk8S'],
#   'user_mentions': ['TonySlayor']},
#  {'text': '@JaylundDavis Bitch get a life😭😂😂',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['JaylundDavis']},
#  {'text': 'RT @kenarion19: I......just.....wanna.....get......through......the.......semester https://t.co/0tM2C9BrSU',
#   'hashtags': [],
#   'urls': ['https://t.co/0tM2C9BrSU'],
#   'user_mentions': ['kenarion19']},
#  {'text': 'My baby be sleeping so peacefully 😢. I only let him sleep when I get to watch him lmfaoo',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @AndrewYang: I would get rid of the tampon tax. 👍 https://t.co/5VOeeyI5Qa',
#   'hashtags': [],
#   'urls': ['https://t.co/5VOeeyI5Qa'],
#   'user_mentions': ['AndrewYang']},
#  {'text': 'I can’t believe this hoe Destinee’',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'I need some friends',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'Everything get on my nerves 🤦🏽\u200d♀️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @sweatsXstew: I’ll Never Understand How Women Deal With Men On The Regular &amp; Scared To Ask Them For Shit...Ion Get It 🥴',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['sweatsXstew']},
#  {'text': 'Transparency is so important 🙇🏽\u200d♀️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @jackieedelgado: me everytime I listen to Jhené Aiko https://t.co/482D6Um9NR',
#   'hashtags': [],
#   'urls': ['https://t.co/482D6Um9NR'],
#   'user_mentions': ['jackieedelgado']},
#  {'text': 'Everything sweet ain’t sugar coated',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @sweatsXstew: I’m Boffum https://t.co/os7wPvUgUC',
#   'hashtags': [],
#   'urls': ['https://t.co/os7wPvUgUC'],
#   'user_mentions': ['sweatsXstew']},
#  {'text': '@chaseeeec You did not hun',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['chaseeeec']},
#  {'text': '@Slaydriana_ Italiannnn😭',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Slaydriana_']},
#  {'text': '@chaseeeec Bye whore cuz I texted you this morning and ain’t heard back from you 🖕🏽',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['chaseeeec']},
#  {'text': 'Lord pls remove this lazy spirit..😭 still got 6 weeks left in the semester',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'Why tf am I up seriously',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': '@lahstew Happy birthday pretty 💕',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['lahstew']},
#  {'text': 'RT @itsreallymk: even if it wasn’t me, it still wouldn’t be you.. https://t.co/QZPsZOa0Wu',
#   'hashtags': [],
#   'urls': ['https://t.co/QZPsZOa0Wu'],
#   'user_mentions': ['itsreallymk']},
#  {'text': '@itsreallymk Bawdyyyyy😍 how coming mkkkkk',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['itsreallymk']},
#  {'text': '@morganhousel 😂',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['morganhousel']},
#  {'text': '@morganhousel Wasn’t aware they had that on there. Thanks for the heads up!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['morganhousel']},
#  {'text': '@Avicii ❤️🎶',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Avicii']},
#  {'text': '@BetoORourke Twitter follow for donation?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['BetoORourke']},
#  {'text': '@SenSanders Twitter follow for donation?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SenSanders']},
#  {'text': '@elonmusk that is the correct order',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['elonmusk']},
#  {'text': '@snellzilla4 You guys did great, and going to be even greater next year. No one’s fault 😤',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['snellzilla4']},
#  {'text': '@kumailn Silicon Valley is the entire reason why I decided to explore a career in technology. Three weeks ago I got… https://t.co/i5EJOGcr3t',
#   'hashtags': [],
#   'urls': ['https://t.co/i5EJOGcr3t'],
#   'user_mentions': ['kumailn']},
#  {'text': '@LaDodgersTalk To LA....Angels of Anaheim',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['LaDodgersTalk']},
#  {'text': '@RaysBaseball @MLBNetwork Would be great if the game wasn’t at 1:00 on a workday',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['RaysBaseball', 'MLBNetwork']},
#  {'text': "RT @MLBNetwork: Hey @RaysBaseball fans, we've got you covered for all seasons!\n \nRETWEET for a chance at the shirt &amp; jacket pictured here a…",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['MLBNetwork', 'RaysBaseball']},
#  {'text': '@CraigSkitz @TwinGalaxies @WalterDay I remember SGC like it was yesterday, not that I went. I was 12 in 2009 and li… https://t.co/7Uk3499o8b',
#   'hashtags': [],
#   'urls': ['https://t.co/7Uk3499o8b'],
#   'user_mentions': ['CraigSkitz', 'TwinGalaxies', 'WalterDay']},
#  {'text': "@phillamarr @Dodgers @get_repost Third time's the charm? Unless they go up against the Rays 😜",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['phillamarr', 'Dodgers', 'get_repost']},
#  {'text': '@everydaylouie Hi Louie! Found your music on spotify, and that brought me to your art. And I just wanted to tell yo… https://t.co/XZ6IAwKp3L',
#   'hashtags': [],
#   'urls': ['https://t.co/XZ6IAwKp3L'],
#   'user_mentions': ['everydaylouie']},
#  {'text': "@lazygamereviews It's kinda awesome that exist at all, I've never seen any special character memory cards like that before",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['lazygamereviews']},
#  {'text': '@HachetteUS @HarperCollins @MacmillanUSA @penguinrandom @simonschuster Physical books should come with digital down… https://t.co/2ouzPfRc4t',
#   'hashtags': [],
#   'urls': ['https://t.co/2ouzPfRc4t'],
#   'user_mentions': ['HachetteUS',
#    'HarperCollins',
#    'MacmillanUSA',
#    'penguinrandom',
#    'simonschuster']},
#  {'text': '@JDFaria34 Holy fuck faria',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['JDFaria34']},
#  {'text': 'Am I shit or are all the decks they give you in Magic Arena story mode shit? #magic',
#   'hashtags': ['magic'],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @RaysBaseball: RT for a chance to win this signed baseball from:\n\nMinor League Player of the Year, Wander Franco\nMinor League Pitcher of…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['RaysBaseball']},
#  {'text': '@aaronpaul_8 Hi Aaron! Is there a list of theatres Ell Camino will be shown in?',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['aaronpaul_8']},
#  {'text': "@buenothebear Wouldn't mess with that guy",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['buenothebear']},
#  {'text': 'RT @Tesla: Plans for tonight:\n• playing The Sims\n• naming a character Internal Combustion Engine\n• making them go for a swim\n• deleting the…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Tesla']},
#  {'text': '@ossoff Yes!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ossoff']},
#  {'text': 'It’s a good idea to shower before being intimate, human scum is gross. https://t.co/A1gKq3MmMX',
#   'hashtags': [],
#   'urls': ['https://t.co/A1gKq3MmMX'],
#   'user_mentions': []},
#  {'text': '@FullFrontalSamB @iamsambee delicious',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['FullFrontalSamB', 'iamsambee']},
#  {'text': '.@KennedyNation call me',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['KennedyNation']},
#  {'text': '@ChelseaClinton @PIH Heyyyyy Chelsea. &lt;3',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ChelseaClinton', 'PIH']},
#  {'text': '@NateSilver538 @newmuseum I take Nate Silver’s tweets with me to my secret place and touch myself.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['NateSilver538', 'newmuseum']},
#  {'text': '@greggutfeld Fighting the good fight is important, but every once and a while you just need to get on Grindr and knock one out.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['greggutfeld']},
#  {'text': 'Going Live w/ The Jackbox Party Pack 6!\nhttps://t.co/69GEDQR751\n#twitch #StreamingLive #jackboxpartypack6',
#   'hashtags': ['twitch', 'StreamingLive', 'jackboxpartypack6'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': "me and my homie after we've just had sex, knowing we are no longer virgins https://t.co/1BvlX0L7JE",
#   'hashtags': [],
#   'urls': ['https://t.co/1BvlX0L7JE'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ Super Mario Maker 2! then maybe Jackbox?\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #SuperMarioMaker2',
#   'hashtags': ['twitch', 'streaminglive', 'SuperMarioMaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ Super Mario Maker 2! THEN Jackbox!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #supermariomaker2',
#   'hashtags': ['twitch', 'streaminglive', 'supermariomaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': "@ZorbarkTheAlien @yourlocalmime I'll control my guns, you control your yoga.",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['ZorbarkTheAlien', 'yourlocalmime']},
#  {'text': '@yourlocalmime what is happening in this image https://t.co/cGbTiU07yj',
#   'hashtags': [],
#   'urls': ['https://t.co/cGbTiU07yj'],
#   'user_mentions': ['yourlocalmime']},
#  {'text': 'Going Live w/ Mario Kart 8 Deluxe! THEN LATER Jackbox!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #SuperMarioMaker2',
#   'hashtags': ['twitch', 'streaminglive', 'SuperMarioMaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': '@SeanPzo I lost my fucking mind when I found out it was "chuck".',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SeanPzo']},
#  {'text': 'Working on first Standup Comedy Special "Barely Virgin". Feelin pretty good about it. 😳',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'Nathan For You is one of the greatest shows of all time, yet I can only watch a few episodes at a time. Nothing els… https://t.co/Y8xA8PndfA',
#   'hashtags': [],
#   'urls': ['https://t.co/Y8xA8PndfA'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ Super Mario Maker 2! THEN LATER Jackbox!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #SuperMarioMaker2',
#   'hashtags': ['twitch', 'streaminglive', 'SuperMarioMaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ The Jackbox Party Pack 6!\nhttps://t.co/69GEDQR751\n#twitch #JackboxPartyPack6 #JackboxStream',
#   'hashtags': ['twitch', 'JackboxPartyPack6', 'JackboxStream'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': "My local theater isn't showing The Lighthouse or Jojo Rabbit. Don't they know I'm a man of culture.",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'yo @VancityReynolds, I think we might be twins https://t.co/IoTGp7JOvd',
#   'hashtags': [],
#   'urls': ['https://t.co/IoTGp7JOvd'],
#   'user_mentions': ['VancityReynolds']},
#  {'text': 'Going Live w/ Super Mario Maker 2!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #SuperMarioMaker2',
#   'hashtags': ['twitch', 'streaminglive', 'SuperMarioMaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ Super Mario Maker 2!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #SuperMarioMaker2',
#   'hashtags': ['twitch', 'streaminglive', 'SuperMarioMaker2'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': 'Going Live w/ The Marbles Tournament!\nWinner gets a Tier 3 Sub!\nhttps://t.co/69GEDQR751\n#twitch #streaminglive #marbles',
#   'hashtags': ['twitch', 'streaminglive', 'marbles'],
#   'urls': ['https://t.co/69GEDQR751'],
#   'user_mentions': []},
#  {'text': 'ALMOST TIME! Tonight is THE UNEASY MARBLES TOURNAMENT | October 2019! Winner gets a Tier 3 Sub to the channel! ANYO… https://t.co/XMHgovvyUZ',
#   'hashtags': [],
#   'urls': ['https://t.co/XMHgovvyUZ'],
#   'user_mentions': []},
#  {'text': 'last night ... I ascended. \nhttps://t.co/MxVVGZiDQz\n#twitch',
#   'hashtags': ['twitch'],
#   'urls': ['https://t.co/MxVVGZiDQz'],
#   'user_mentions': []},
#  {'text': "@slavooshka UPDATE: Couldn't remember my dream from last night.",
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['slavooshka']},
#  {'text': 'Funding with accountability will do great things for Oregon education. https://t.co/6utTb7Eq87',
#   'hashtags': [],
#   'urls': ['https://t.co/6utTb7Eq87'],
#   'user_mentions': []},
#  {'text': '@CoryBooker So much this!  Different views are ok.  I’d like to see people talk about their plans vs tearing down t… https://t.co/HMDbVNB1HR',
#   'hashtags': [],
#   'urls': ['https://t.co/HMDbVNB1HR'],
#   'user_mentions': ['CoryBooker']},
#  {'text': 'Today I applied for @EmergeOregon.  I’m looking to run for the Beaverton School District sometime in the future.  I… https://t.co/lQYsvZK0aM',
#   'hashtags': [],
#   'urls': ['https://t.co/lQYsvZK0aM'],
#   'user_mentions': ['EmergeOregon']},
#  {'text': '@msbishop Thank you for helping the school!',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['msbishop']},
#  {'text': 'Representing Arco Iris Spanish Immersion School in the Beaverton parade this morning #arcoiris… https://t.co/HWIGCEJggx',
#   'hashtags': ['arcoiris'],
#   'urls': ['https://t.co/HWIGCEJggx'],
#   'user_mentions': []},
#  {'text': 'How 4 Companies Struggle to Navigate Trump’s Trade Uncertainty https://t.co/gSISJ0rHdZ\n\nMy job entails working on t… https://t.co/RawxKFW2uT',
#   'hashtags': [],
#   'urls': ['https://t.co/gSISJ0rHdZ', 'https://t.co/RawxKFW2uT'],
#   'user_mentions': []},
#  {'text': 'RT @DOEChancellor: Why culturally responsive education matters: Never mind the naysayers - New York Daily News https://t.co/fE1Pl8XnT8',
#   'hashtags': [],
#   'urls': ['https://t.co/fE1Pl8XnT8'],
#   'user_mentions': ['DOEChancellor']},
#  {'text': 'I also had ACA for awhile recently.  The deductible was high &amp; too few providers too choose from.  I was super than… https://t.co/Vskgpr9kL3',
#   'hashtags': [],
#   'urls': ['https://t.co/Vskgpr9kL3'],
#   'user_mentions': []},
#  {'text': '@msbishop My old one was even better than the one I have now.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['msbishop']},
#  {'text': '@msbishop I love mine!  $500 deductible and $20 copays.',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['msbishop']},
#  {'text': 'This logic was the basis for part of some equity training I took last weekend.  I hope more schools adopt this kind… https://t.co/dFEa0R6G4D',
#   'hashtags': [],
#   'urls': ['https://t.co/dFEa0R6G4D'],
#   'user_mentions': []},
#  {'text': 'Because we all need a break from politics sometimes...., https://t.co/R6zpOXc25R',
#   'hashtags': [],
#   'urls': ['https://t.co/R6zpOXc25R'],
#   'user_mentions': []},
#  {'text': 'Important topic st this year’s conference. https://t.co/6zHWrBiRHq',
#   'hashtags': [],
#   'urls': ['https://t.co/6zHWrBiRHq'],
#   'user_mentions': []},
#  {'text': 'Learning with my fellow school board members at the OSBA summer conference https://t.co/wUiSbKW2ew',
#   'hashtags': [],
#   'urls': ['https://t.co/wUiSbKW2ew'],
#   'user_mentions': []},
#  {'text': 'Always a great conference https://t.co/ji5Q5ILCD2',
#   'hashtags': [],
#   'urls': ['https://t.co/ji5Q5ILCD2'],
#   'user_mentions': []},
#  {'text': 'I’ve been told I’m bossy at times.  I call it leadership! https://t.co/URk2Fbf2gQ',
#   'hashtags': [],
#   'urls': ['https://t.co/URk2Fbf2gQ'],
#   'user_mentions': []},
#  {'text': 'RT @SheShouldRun: "Regardless of whether they’re mothers, women face a gendered double bind: Women without children are seen as ambitious a…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['SheShouldRun']},
#  {'text': 'This is one of many reasons why Education funding is so critical.  #beavertonschool https://t.co/OAFgZ7rUcx',
#   'hashtags': ['beavertonschool'],
#   'urls': ['https://t.co/OAFgZ7rUcx'],
#   'user_mentions': []},
#  {'text': 'Good read!   https://t.co/zx6RwnkHZz',
#   'hashtags': [],
#   'urls': ['https://t.co/zx6RwnkHZz'],
#   'user_mentions': []},
#  {'text': "Once You're My Student, You're Always My Student https://t.co/B0FWSfcD36 via @WeAreTeachers",
#   'hashtags': [],
#   'urls': ['https://t.co/B0FWSfcD36'],
#   'user_mentions': ['WeAreTeachers']},
#  {'text': 'Song of Durin (Complete Edition) - Clamavi De Profundis https://t.co/5r4ivlKARm via @YouTube',
#   'hashtags': [],
#   'urls': ['https://t.co/5r4ivlKARm'],
#   'user_mentions': ['YouTube']},
#  {'text': '@mareckproducti1  check out these guys, it is worth it: https://t.co/PhQfzfFZgo',
#   'hashtags': [],
#   'urls': ['https://t.co/PhQfzfFZgo'],
#   'user_mentions': ['mareckproducti1']},
#  {'text': '@AlecSteeleSteel. A great song for your fantastic forge! https://t.co/PhQfzfFZgo',
#   'hashtags': [],
#   'urls': ['https://t.co/PhQfzfFZgo'],
#   'user_mentions': ['AlecSteeleSteel']},
#  {'text': '@jordanbpeterson More art breathing forth strength to the world.\n\nhttps://t.co/6retSkmF8E',
#   'hashtags': [],
#   'urls': ['https://t.co/6retSkmF8E'],
#   'user_mentions': ['jordanbpeterson']},
#  {'text': 'Fantastic. https://t.co/5prQyYZULz',
#   'hashtags': [],
#   'urls': ['https://t.co/5prQyYZULz'],
#   'user_mentions': []},
#  {'text': '@jordanbpeterson Music and beauty for the soul. Be well.  https://t.co/beEESPeWIJ',
#   'hashtags': [],
#   'urls': ['https://t.co/beEESPeWIJ'],
#   'user_mentions': ['jordanbpeterson']},
#  {'text': 'https://t.co/o7mA444teI',
#   'hashtags': [],
#   'urls': ['https://t.co/o7mA444teI'],
#   'user_mentions': []},
#  {'text': '#NewProfilePic https://t.co/IekL4A9hCO',
#   'hashtags': ['NewProfilePic'],
#   'urls': ['https://t.co/IekL4A9hCO'],
#   'user_mentions': []},
#  {'text': 'RT @h0egenic: me running to twitter to overshare about my probIems https://t.co/HnoqB8fRAN',
#   'hashtags': [],
#   'urls': ['https://t.co/HnoqB8fRAN'],
#   'user_mentions': ['h0egenic']},
#  {'text': 'RT @MLB: ALTUVE SENDS THE @ASTROS TO THE #WORLDSERIES! https://t.co/NYx1yzRFDY',
#   'hashtags': ['WORLDSERIES'],
#   'urls': ['https://t.co/NYx1yzRFDY'],
#   'user_mentions': ['MLB', 'astros']},
#  {'text': 'https://t.co/2iFZQfPR4w',
#   'hashtags': [],
#   'urls': ['https://t.co/2iFZQfPR4w'],
#   'user_mentions': []},
#  {'text': '@noriega_joaquin Happy Belated Birthday again 🙃',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['noriega_joaquin']},
#  {'text': '@Sixela_Selaznog Missing out 😋',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Sixela_Selaznog']},
#  {'text': 'RT @mirandaimani: When the internet was truly at its peak https://t.co/GnYWdFuEYT',
#   'hashtags': [],
#   'urls': ['https://t.co/GnYWdFuEYT'],
#   'user_mentions': ['mirandaimani']},
#  {'text': 'RT @anthonygonnn: ITS TOO EARLY FOR THIS 😂😂 https://t.co/PMuNZK9JMH',
#   'hashtags': [],
#   'urls': ['https://t.co/PMuNZK9JMH'],
#   'user_mentions': ['anthonygonnn']},
#  {'text': 'I just... These poor scientists https://t.co/GCCNZZnkDb',
#   'hashtags': [],
#   'urls': ['https://t.co/GCCNZZnkDb'],
#   'user_mentions': []},
#  {'text': 'RT @FourthRayBeauty: 🌈#GIVEAWAY  🌈\n\nThe restock we have all been waiting for Head In The Clouds #FACEMILKS KIT! We partnered with our sis f…',
#   'hashtags': ['GIVEAWAY', 'FACEMILKS'],
#   'urls': [],
#   'user_mentions': ['FourthRayBeauty']},
#  {'text': 'RT @Jay_papiiii: I was about to go pay my rent and my unborn son handed me this cash and said, “Dad, It’s time for me to start carrying my…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Jay_papiiii']},
#  {'text': 'RT @Nlyssaaa: My dad randomly sent me this and it’s my new favorite thing https://t.co/jmeP66dYp1',
#   'hashtags': [],
#   'urls': ['https://t.co/jmeP66dYp1'],
#   'user_mentions': ['Nlyssaaa']},
#  {'text': 'RT @cloudymal: me when i’m not receiving enough attention https://t.co/brjwGg75uY',
#   'hashtags': [],
#   'urls': ['https://t.co/brjwGg75uY'],
#   'user_mentions': ['cloudymal']},
#  {'text': 'My date turned into waiting for 2 1/2 hrs for the new iPhone 😪',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': []},
#  {'text': 'RT @Kohls: Heads up! You can win a $1,000 Kohl’s Gift Card to use on home decor from Scott Living—arriving Oct. 10. Retweet this post with…',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Kohls']},
#  {'text': 'RT @Mr_Meowwwgi: This punishment is not working... https://t.co/Gky81iQA0q',
#   'hashtags': [],
#   'urls': ['https://t.co/Gky81iQA0q'],
#   'user_mentions': ['Mr_Meowwwgi']},
#  {'text': 'RT @TMobile: Win a trip to the Fall Classic 🍁 from #TMobileTuesdays. \n\nRT for a chance to win 2 tickets to Game 1 of the @MLB #WorldSeries🏆…',
#   'hashtags': ['TMobileTuesdays', 'WorldSeries'],
#   'urls': [],
#   'user_mentions': ['TMobile', 'MLB']},
#  {'text': '@Sixela_Selaznog If sucking means winning that fine by me 🤷🏻\u200d♀️',
#   'hashtags': [],
#   'urls': [],
#   'user_mentions': ['Sixela_Selaznog']}]

# %% [markdown]
# [NLTK Stopwords](https://pythonspot.com/nltk-stop-words/)

# %%
STOPWORDS = stopwords.words('english') + stopwords.words('spanish')
# TODO: decide whether or not to remove tweets that are from retweets altogether
more_stop_words = ['rt']
STOPWORDS += more_stop_words
STOPWORDS
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
#  'vosotras',
#  'os',
#  'mío',
#  'mía',
#  'míos',
#  'mías',
#  'tuyo',
#  'tuya',
#  'tuyos',
#  'tuyas',
#  'suyo',
#  'suya',
#  'suyos',
#  'suyas',
#  'nuestro',
#  'nuestra',
#  'nuestros',
#  'nuestras',
#  'vuestro',
#  'vuestra',
#  'vuestros',
#  'vuestras',
#  'esos',
#  'esas',
#  'estoy',
#  'estás',
#  'está',
#  'estamos',
#  'estáis',
#  'están',
#  'esté',
#  'estés',
#  'estemos',
#  'estéis',
#  'estén',
#  'estaré',
#  'estarás',
#  'estará',
#  'estaremos',
#  'estaréis',
#  'estarán',
#  'estaría',
#  'estarías',
#  'estaríamos',
#  'estaríais',
#  'estarían',
#  'estaba',
#  'estabas',
#  'estábamos',
#  'estabais',
#  'estaban',
#  'estuve',
#  'estuviste',
#  'estuvo',
#  'estuvimos',
#  'estuvisteis',
#  'estuvieron',
#  'estuviera',
#  'estuvieras',
#  'estuviéramos',
#  'estuvierais',
#  'estuvieran',
#  'estuviese',
#  'estuvieses',
#  'estuviésemos',
#  'estuvieseis',
#  'estuviesen',
#  'estando',
#  'estado',
#  'estada',
#  'estados',
#  'estadas',
#  'estad',
#  'he',
#  'has',
#  'ha',
#  'hemos',
#  'habéis',
#  'han',
#  'haya',
#  'hayas',
#  'hayamos',
#  'hayáis',
#  'hayan',
#  'habré',
#  'habrás',
#  'habrá',
#  'habremos',
#  'habréis',
#  'habrán',
#  'habría',
#  'habrías',
#  'habríamos',
#  'habríais',
#  'habrían',
#  'había',
#  'habías',
#  'habíamos',
#  'habíais',
#  'habían',
#  'hube',
#  'hubiste',
#  'hubo',
#  'hubimos',
#  'hubisteis',
#  'hubieron',
#  'hubiera',
#  'hubieras',
#  'hubiéramos',
#  'hubierais',
#  'hubieran',
#  'hubiese',
#  'hubieses',
#  'hubiésemos',
#  'hubieseis',
#  'hubiesen',
#  'habiendo',
#  'habido',
#  'habida',
#  'habidos',
#  'habidas',
#  'soy',
#  'eres',
#  'es',
#  'somos',
#  'sois',
#  'son',
#  'sea',
#  'seas',
#  'seamos',
#  'seáis',
#  'sean',
#  'seré',
#  'serás',
#  'será',
#  'seremos',
#  'seréis',
#  'serán',
#  'sería',
#  'serías',
#  'seríamos',
#  'seríais',
#  'serían',
#  'era',
#  'eras',
#  'éramos',
#  'erais',
#  'eran',
#  'fui',
#  'fuiste',
#  'fue',
#  'fuimos',
#  'fuisteis',
#  'fueron',
#  'fuera',
#  'fueras',
#  'fuéramos',
#  'fuerais',
#  'fueran',
#  'fuese',
#  'fueses',
#  'fuésemos',
#  'fueseis',
#  'fuesen',
#  'sintiendo',
#  'sentido',
#  'sentida',
#  'sentidos',
#  'sentidas',
#  'siente',
#  'sentid',
#  'tengo',
#  'tienes',
#  'tiene',
#  'tenemos',
#  'tenéis',
#  'tienen',
#  'tenga',
#  'tengas',
#  'tengamos',
#  'tengáis',
#  'tengan',
#  'tendré',
#  'tendrás',
#  'tendrá',
#  'tendremos',
#  'tendréis',
#  'tendrán',
#  'tendría',
#  'tendrías',
#  'tendríamos',
#  'tendríais',
#  'tendrían',
#  'tenía',
#  'tenías',
#  'teníamos',
#  'teníais',
#  'tenían',
#  'tuve',
#  'tuviste',
#  'tuvo',
#  'tuvimos',
#  'tuvisteis',
#  'tuvieron',
#  'tuviera',
#  'tuvieras',
#  'tuviéramos',
#  'tuvierais',
#  'tuvieran',
#  'tuviese',
#  'tuvieses',
#  'tuviésemos',
#  'tuvieseis',
#  'tuviesen',
#  'teniendo',
#  'tenido',
#  'tenida',
#  'tenidos',
#  'tenidas',
#  'tened',
#  'rt']

# %%
def word_extraction(tweet_dictionary, stopwords = STOPWORDS):  
    sentence = tweet_dictionary['text']
    hashtags = ['#' + s for s in tweet_dictionary['hashtags']]
    urls = tweet_dictionary['urls']
    user_mentions = ['@' + s for s in tweet_dictionary['user_mentions']]
    
    ignore = hashtags + urls + user_mentions

    words = sentence.split()  
    
    cleaned_text = []
    
    for word in words:
        cleaned_word = re.sub("[^\w]", "",  word)
        if (not word in ignore) and (not word.lower() in stopwords) and (word.isalpha()) and (len(cleaned_word) > 0):
            cleaned_text.append(cleaned_word.lower())
    return cleaned_text

# %%
test_tweet = tweets_data[0]
print(word_extraction(test_tweet))
print(test_tweet)
# Out:
# ['coming', 'back', 'slc']
# {'text': 'RT @utahjazz: All-Star is coming back to SLC in 2023 ❄️🏀🌟 https://t.co/yHaX78p8Id', 'hashtags': [], 'urls': ['https://t.co/yHaX78p8Id'], 'user_mentions': ['utahjazz']}

# %%
tweets_text = []
for tweet in tweets_data:
    tweets_text.extend(word_extraction(tweet))
print("Extracted words:", tweets_text)
# Out:
# Extracted words: ['coming', 'back', 'slc', 'giving', 'away', 'tickets', 'home', 'opener', 'oklahoma', 'city', 'giveaway', 'corsair', 'hitting', 'someone', 'new', 'retweet', 'like', 'post', 'follow', 'flash', 'win', 'tickets', 'vs', 'preseason', 'game', 'dinner', 'hires', 'big', 'h', 'giving', 'away', 'tickets', 'preseason', 'game', 'sacramento', 'fortnite', 'demonized', 'children', 'turn', 'back', 'normal', 'gaming', 'give', 'someone', 'random', 'retweets', 'pay', 'following', 'dm', 'ends', 'win', 'tickets', 'preseason', 'game', 'monday', 'october', 'dinner', 'guys', 'could', 'please', 'help', 'donate', 'even', 'retweet', 'tweet', 'thank', 'enjoying', 'season', 'apex', 'lot', 'battlepass', 'check', 'give', 'cash', 'someone', 'random', 'retweets', 'beautiful', 'afternoon', 'following', 'dm', 'boys', 'back', 'win', 'suite', 'tickets', 'first', 'preseason', 'game', 'season', 'battle', 'pass', 'winners', 'announced', 'retweet', 'tweet', 'must', 'following', 'give', 'someone', 'random', 'retweets', 'yup', 'pay', 'following', 'dm', 'hell', 'tell', 'em', 'lucas', 'lcd', 'glass', 'drop', 'hit', 'unlocked', 'thinking', 'game', 'cat', 'learned', 'open', 'doors', 'every', 'year', 'get', 'closer', 'ditching', 'iphone', 'imessage', 'im', 'feeling', 'lucky', 'cant', 'wait', 'brag', 'going', 'give', 'away', 'another', 'geforce', 'rtx', 'weekend', 'instructions', 'retweet', 'beautiful', 'day', 'stardew', 'valley', 'halloween', 'playstation', 'launches', 'holiday', 'wow', 'trending', 'thanks', 'guys', 'retweet', 'tweet', 'entered', 'win', 'free', 'slice', 'probably', 'cheating', 'right', 'changed', 'fb', 'profile', 'pic', 'older', 'picture', 'bc', 'liked', 'parents', 'thought', 'dont', 'think', 'favorite', 'noodles', 'employee', 'works', 'anymore', 'miss', 'see', 'kinda', 'rude', 'cost', 'whole', 'grand', 'meet', 'chris', 'hemsworth', 'tom', 'holland', 'comic', 'sold', 'lmao', 'person', 'delivered', 'uber', 'eats', 'literally', 'ate', 'half', 'much', 'chocolate', 'disgusting', 'man', 'polls', 'opened', 'voters', 'general', 'polling', 'stations', 'went', 'operation', 'island', 'discussion', 'whether', 'photography', 'art', 'dated', 'work', 'makes', 'amazon', 'forest', 'continues', 'burn', 'thousands', 'hectares', 'forestry', 'habitats', 'destroyed', 'produces', 'never', 'felt', 'vulnerable', 'nervous', 'leadership', 'conference', 'past', 'couple', 'years', 'really', 'fallen', 'love', 'vlog', 'much', 'fun', 'please', 'dig', 'quarters', 'dimes', 'gap', 'couch', 'pop', 'downtown', 'congrats', 'opening', 'first', 'na', 'boutique', 'oakridge', 'lot', 'going', 'busy', 'getting', 'organized', 'feels', 'big', 'congratulations', 'nomination', 'great', 'interview', 'spread', 'photobox', 'great', 'see', 'excited', 'announce', 'opening', 'photography', 'studio', 'heart', 'dt', 'happy', 'holidays', 'much', 'good', 'things', 'new', 'rosa', 'viola', 'new', 'face', 'bts', 'bg', 'canada', 'photo', 'super', 'fun', 'session', 'widejkophotography', 'widejkoportrait', 'little', 'black', 'portraits', 'sale', 'jan', 'shooting', 'project', 'karma', 'witty', 'woman', 'witty', 'beauty', 'pleasure', 'capturing', 'beauty', 'three', 'assignments', 'wish', 'u', 'wait', 'stream', 'tonight', 'may', 'get', 'keep', 'wait', 'stream', 'tonight', 'twitch', 'rolled', 'new', 'stream', 'manager', 'feature', 'going', 'extremely', 'fyi', 'look', 'like', 'package', 'going', 'arrive', 'sure', 'going', 'around', 'short', 'think', 'streaming', 'today', 'waiting', 'shot', 'ready', 'btw', 'pickles', 'shipping', 'dm', 'tracking', 'aweee', 'one', 'thing', 'focusing', 'help', 'revitalize', 'great', 'game', 'v', 'wanna', 'hear', 'bowl', 'tony', 'slayor', 'bitch', 'get', 'baby', 'sleeping', 'peacefully', 'let', 'sleep', 'get', 'watch', 'lmfaoo', 'would', 'get', 'rid', 'tampon', 'believe', 'hoe', 'need', 'friends', 'everything', 'get', 'nerves', 'never', 'understand', 'women', 'deal', 'men', 'regular', 'scared', 'ask', 'get', 'transparency', 'important', 'everytime', 'listen', 'jhené', 'aiko', 'ev ...

# %%
tweets_hashtags = []
for tweet in tweets_data:
        tweets_hashtags.extend(tweet['hashtags'])
print("Extracted hashtags:", tweets_hashtags)
# Out:
# Extracted hashtags: ['VivintArena', 'PS5', 'FreePizzaFriday', 'photographer', 'vancouverprofessional', 'canadianphotographer', 'photographer', 'vancouverprofessional', 'vancouverbusiness', 'photoboxvancouver', 'vancouverevent', 'Vancouver', 'happyholidays', 'vancouverphotography', 'photographer', 'vancovuerfashion', 'photoshoot', 'photography', 'vancouver', 'vancouverbusiness', 'activewear', 'lookbook', 'vancouverprofessional', 'busybusy', 'MakeFirestormFree', 'magic', 'twitch', 'StreamingLive', 'jackboxpartypack6', 'twitch', 'streaminglive', 'SuperMarioMaker2', 'twitch', 'streaminglive', 'supermariomaker2', 'twitch', 'streaminglive', 'SuperMarioMaker2', 'twitch', 'streaminglive', 'SuperMarioMaker2', 'twitch', 'JackboxPartyPack6', 'JackboxStream', 'twitch', 'streaminglive', 'SuperMarioMaker2', 'twitch', 'streaminglive', 'SuperMarioMaker2', 'twitch', 'streaminglive', 'marbles', 'twitch', 'arcoiris', 'beavertonschool', 'NewProfilePic', 'WORLDSERIES', 'GIVEAWAY', 'FACEMILKS', 'TMobileTuesdays', 'WorldSeries']

# %%
def get_freq_map(my_list): 
    freq = {} 
    for item in my_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
    return freq

def get_top_freq(my_list, top_count):
    freq = get_freq_map(my_list)
    freq = sorted(freq.items(), key=lambda item: item[1], reverse = True)
    
    if len(freq) <= top_count:
        return freq
    else:
        return freq[:10]

# %%
tweets_text_freq = get_top_freq(tweets_text, WORD_FREQ_LIMIT)
print("top {0} most freq words:".format(WORD_FREQ_LIMIT))
tweets_text_freq
# Out:
# top 10 most freq words:
# [('going', 15),
#  ('live', 9),
#  ('win', 8),
#  ('game', 8),
#  ('get', 8),
#  ('new', 7),
#  ('retweet', 7),
#  ('great', 7),
#  ('super', 7),
#  ('tickets', 6)]

# %%
tweets_hashtags_freq = get_top_freq(tweets_hashtags, WORD_FREQ_LIMIT)
print("top {0} most freq hashtags:".format(WORD_FREQ_LIMIT))
tweets_hashtags_freq
# Out:
# top 10 most freq hashtags:
# [('twitch', 10),
#  ('streaminglive', 7),
#  ('SuperMarioMaker2', 5),
#  ('photographer', 3),
#  ('vancouverprofessional', 3),
#  ('vancouverbusiness', 2),
#  ('VivintArena', 1),
#  ('PS5', 1),
#  ('FreePizzaFriday', 1),
#  ('canadianphotographer', 1)]
